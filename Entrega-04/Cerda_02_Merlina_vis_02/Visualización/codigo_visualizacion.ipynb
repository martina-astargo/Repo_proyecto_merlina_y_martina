# %%
import altair as alt
import pandas as pd # Import pandas
from vega_datasets import data

source = pd.read_csv("/content/database_limpia_intento2.csv", sep=';') # Load the CSV using pandas, trying semicolon as delimiter

print(source.columns) # Print column names to identify the correct one

alt.Chart(source).mark_circle(size=60).encode(
    x='año:O', # Explicitly set 'año' as an ordinal field to show all year labels
    y='canal',
    color='genero',
    tooltip=['teleserie', 'genero', 'año', 'canal']
).interactive()
# Out:
# Index(['personaje', 'genero', 'roles', 'teleserie', 'genero-teleserie',
#        'canal', 'año', 'tipo-de-accion', 'estado-civil', 'fuerza-actua'],
#       dtype='object')
# alt.Chart(...)
