# %%
import pandas as pd
import altair as alt

# cargar datos
df = pd.read_csv("/content/teleseries_database_limpia.csv", sep=";")

# Echar un vistazo
df.head(29)
# Out:
#        DÉCADA  AÑO TELESERIE  CANAL                 TELESERIES  \
# 0   1980-1989         1981.0    T13               La madrastra
# 1   1980-1989         1983.0    T13      La noche del cobarde
# 2   1980-1989         1984.0    TVN               La torre 10
# 3   1980-1989         1984.0    T13             Las herederas
# 4   1980-1989         1984.0    T13               Los títeres
# 5   1990-1999         1990.0    T13                 ¿Te conté?
# 6   1990-1999         1996.0    TVN                   Sucupira
# 7   1990-1999         1997.0    T13             Playa salvaje
# 8   1990-1999         1998.0    TVN                     Iorana
# 9   1990-1999         1999.0    TVN                  La fiera
# 10  1990-1999         1999.0    TVN                  Aquelarre
# 11  2000-2009         2000.0   TVN                      Romané
# 12  2000-2009         2001.0    TVN         Amores de Mercado
# 13  2000-2009         2001.0    TVN              Pampa Ilusión
# ...
